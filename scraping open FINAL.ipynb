# %% [markdown]
# # Scraping articles from Open website

# %%
#I import the necessary packages to webscrape
import requests
from lxml.html import fromstring
import time
import pandas as pd

#I create a function to extract the information from the website
def fetch_article_html(url):
    response = requests.get(url)
    return response.text

#I create a function to extract the text of the article and to put together all of the paragraphs
def extract_article_text(html):
    tree = fromstring(html)
    article_text = tree.xpath("//div[3]/p/text() | //div[2]/p/a/text() | //div[2]/p/strong/text()")
    return ' '.join(article_text)

#I define the url of the website and loop over the 68 pages present in the section I am interested in
MAXPAGES = 68
baseurl = "https://www.open.online/temi/elezioni-politiche-2022/page/"
allurls = [f"{baseurl}{i}/" for i in range(1, MAXPAGES + 1)]

#I create a list in which to store the information
articles_data = []

#I loop over every url and check if the page exist. Then I extract the link and title of each article from the website and 
#then for every link (so for every aerticle) I retrieve the test of that article. I start from the third page because the 
#articles in the first page were written after November 2022, while in all of the other news outlets they were not written 
#after October 2022
for url in allurls[2:]:
    try:
        #I fetch the HTML source from the website
        response = requests.get(url)
        if response.status_code == 404:
            print("Page not found:", url)
            continue
        htmlsource = response.text

        tree = fromstring(htmlsource)

        #I find the links and titles
        article_links = tree.xpath("//article/div/h2/a/@href")
        article_title = tree.xpath("//article/div/h2/a/text()")

        #I extract the article texts
        for link, title in zip(article_links, article_title):
            try:
                #I fetch the HTML source of each article page
                article_html = fetch_article_html(link)

                #I extract the full article text
                article_text = extract_article_text(article_html)

                #I append the links, titles and text to the list created above
                articles_data.append({
                    'Link': link,
                    'Title': title,
                    'Text': article_text
                })

                #I delay of 1 second before the next request
                time.sleep(1)  

            except requests.exceptions.RequestException as e:
                print("Connection error:", e)
                continue

    except requests.exceptions.RequestException as e:
        print("Connection error:", e)
        continue

# I create a dataframe from the articles data dictionary
df = pd.DataFrame(articles_data)

# Irint the DataFrame
print(df)
# Out:
#                                                   Link  \
# 0    https://www.open.online/2022/09/29/elezioni-po...
# 1    https://www.open.online/2022/09/29/elezioni-po...
# 2    https://www.open.online/2022/09/29/commissione...
# 3    https://www.open.online/2022/09/29/elezioni-po...
# 4    https://www.open.online/2022/09/29/governo-mel...
# ..                                                 ...
# 787  https://www.open.online/2022/07/17/centrodestr...
# 788  https://www.open.online/2022/07/17/crisi-di-go...
# 789  https://www.open.online/2022/07/16/crisi-gover...
# 790  https://www.open.online/2022/07/16/sondaggi-el...
# 791  https://www.open.online/2022/07/15/crisi-di-go...
#
#                                                  Title  \
# 0    Usa, la Casa Bianca chiarisce parole di Biden ...
# 1    Fiano, Prestigiacomo, Paragone, Sensi: chi las...
# 2    Lo stop dell’Europa a Giorgia Meloni sul reddi...
# 3    Stefano Bonaccini: «Io prossimo segretario Pd?...
# 4    Vicepremier, agricoltura, interni, infrastrutt...
# ..                                                 ...
# 787  Centrodestra diviso sul voto, Fi e Lega frenan...
# 788  Dopo l’irrigidimento di Conte la crisi è quasi...
# 789  Crisi di governo, Renzi: «O Draghi fa il bis a...
# 790  Chi vince le elezioni se si va al voto anticip...
# 791  Cacciari: «Mattarella non ci porterà mai al vo...
#
#                                                   Text
# 0    Dopo le dichiarazioni poco chiare di   sulle e...
# 1    C’è chi lo sapeva e chi è stato colto alla spr...
# 2    Il   non va abolito. Bisogna applicarlo meglio...
# 3    « ». Ad affermarlo è il presidente dell’Emilia...
# 4    L’  tra Giorgia Meloni e Matteo Salvini è serv...
# ..                                                 ...
# 787  Il   scricchiola sotto il peso della crisi di ...
# 788  I tessitori sono rimasti all’opera fino alle 2...
# 789  , a ruota libera all’assemblea di Italia Viva ...
# 790  Su cinque diversi scenari per la simulazione d...
# 791  Il filosofo   pensa che   non porterà l’Italia...
#
# [792 rows x 3 columns]

# %%
#I transform the dataframe into a csv file, I add a column and I save it 
articles_Open = pd.DataFrame.from_dict(articles_data)
articles_Open['News outlet'] = pd.Series('Open', index=articles_Open.index)
articles_Open.to_csv('articles_Open.csv', index=False)
#I check that everything went smoothly
articles_Open.head()
# Out:
#                                                 Link  \
# 0  https://www.open.online/2022/09/29/elezioni-po...
# 1  https://www.open.online/2022/09/29/elezioni-po...
# 2  https://www.open.online/2022/09/29/commissione...
# 3  https://www.open.online/2022/09/29/elezioni-po...
# 4  https://www.open.online/2022/09/29/governo-mel...
#
#                                                Title  \
# 0  Usa, la Casa Bianca chiarisce parole di Biden ...
# 1  Fiano, Prestigiacomo, Paragone, Sensi: chi las...
# 2  Lo stop dell’Europa a Giorgia Meloni sul reddi...
# 3  Stefano Bonaccini: «Io prossimo segretario Pd?...
# 4  Vicepremier, agricoltura, interni, infrastrutt...
#
#                                                 Text News outlet
# 0  Dopo le dichiarazioni poco chiare di   sulle e...        Open
# 1  C’è chi lo sapeva e chi è stato colto alla spr...        Open
# 2  Il   non va abolito. Bisogna applicarlo meglio...        Open
# 3  « ». Ad affermarlo è il presidente dell’Emilia...        Open
# 4  L’  tra Giorgia Meloni e Matteo Salvini è serv...        Open

# %% [markdown]
# I create a condition with a list of rows and then use it to extract those rows from the dataset and put into another dataset,
# which will serve for the labeled dataset. Then, I drop those columns from the original dataset, as this is the unlabeled dataset.

# %%
condition = list(range(1, 30)) + list(range(380, 454)) + list(range(760, 791))
articlesOpen_labeled = articles_Open.loc[condition].copy()
articlesOpen_labeled.head()
articlesOpen_labeled.to_csv('articlesOpen_labeled.csv', index=False)
articlesOpen_unlabeled = articles_Open.drop(list(range(1, 30)) + list(range(380, 454)) + list(range(760, 791)))
articlesOpen_unlabeled.to_csv('articlesOpen_unlabeled.csv', index=False)
#I restore the indexes of both dataframes
articlesOpen_labeled.reset_index(drop=True, inplace=True)
articlesOpen_unlabeled.reset_index(drop=True, inplace=True)

# %%
#I check that everything went smoothly
articlesOpen_unlabeled
# Out:
#                                                   Link  \
# 0    https://www.open.online/2022/09/29/elezioni-po...
# 1    https://www.open.online/2022/09/27/elezioni-po...
# 2    https://www.open.online/2022/09/27/governo-mel...
# 3    https://www.open.online/2022/09/26/elezioni-po...
# 4    https://www.open.online/2022/09/26/elezioni-po...
# ..                                                 ...
# 653  https://www.open.online/2022/07/24/di-battista...
# 654  https://www.open.online/2022/07/24/elodie-vs-p...
# 655  https://www.open.online/2022/07/24/m5s-conte-l...
# 656  https://www.open.online/2022/07/24/letta-rottu...
# 657  https://www.open.online/2022/07/15/crisi-di-go...
#
#                                                  Title  \
# 0    Usa, la Casa Bianca chiarisce parole di Biden ...
# 1    Guido Crosetto: «Con Meloni premier sarà il go...
# 2    Il totoministri del nuovo governo Meloni (ment...
# 3    Usa, l’agenzia di rating S&P Global sulle elez...
# 4    Elezioni politiche, i seggi stimati per Camera...
# ..                                                 ...
# 653  «Nemici dei lavoratori», «Siete come Meloni»: ...
# 654  Elodie, attacco social a Fratelli d’Italia: «H...
# 655  Ora che è finita col Pd Conte pensa alle liste...
# 656  Letta contraccambia l’addio di Conte: «Con il ...
# 657  Cacciari: «Mattarella non ci porterà mai al vo...
#
#                                                   Text News outlet
# 0    Dopo le dichiarazioni poco chiare di   sulle e...        Open
# 1    «Se qualcuno pensa di fare il nuovo esecutivo ...        Open
# 2    Dopo la vittoria alle elezioni la   si prepara...        Open
# 3    «Il nuovo governo italiano si trova davanti a ...        Open
# 4    Il     le elezioni e ora la politica si avvia ...        Open
# ..                                                 ...         ...
# 653  «Il 25 settembre la sfida sarà tra me e  ». Le...        Open
# 654  «A me sinceramente  ». Così l’artista pop   su...        Open
# 655  Le parole pronunciate dai due più diretti inte...        Open
# 656  La   con 5 stelle «in queste elezioni è  ». Co...        Open
# 657  Il filosofo   pensa che   non porterà l’Italia...        Open
#
# [658 rows x 4 columns]

# %%
#I check that everything went smoothly
articlesOpen_labeled
# Out:
#                                                   Link  \
# 0    https://www.open.online/2022/09/29/elezioni-po...
# 1    https://www.open.online/2022/09/29/commissione...
# 2    https://www.open.online/2022/09/29/elezioni-po...
# 3    https://www.open.online/2022/09/29/governo-mel...
# 4    https://www.open.online/2022/09/29/governo-mel...
# ..                                                 ...
# 129  https://www.open.online/2022/07/17/crisi-di-go...
# 130  https://www.open.online/2022/07/17/centrodestr...
# 131  https://www.open.online/2022/07/17/crisi-di-go...
# 132  https://www.open.online/2022/07/16/crisi-gover...
# 133  https://www.open.online/2022/07/16/sondaggi-el...
#
#                                                  Title  \
# 0    Fiano, Prestigiacomo, Paragone, Sensi: chi las...
# 1    Lo stop dell’Europa a Giorgia Meloni sul reddi...
# 2    Stefano Bonaccini: «Io prossimo segretario Pd?...
# 3    Vicepremier, agricoltura, interni, infrastrutt...
# 4    Così il governo Meloni cambierà reddito di cit...
# ..                                                 ...
# 129  Lega, oggi altro vertice per decidere la linea...
# 130  Centrodestra diviso sul voto, Fi e Lega frenan...
# 131  Dopo l’irrigidimento di Conte la crisi è quasi...
# 132  Crisi di governo, Renzi: «O Draghi fa il bis a...
# 133  Chi vince le elezioni se si va al voto anticip...
#
#                                                   Text News outlet
# 0    C’è chi lo sapeva e chi è stato colto alla spr...        Open
# 1    Il   non va abolito. Bisogna applicarlo meglio...        Open
# 2    « ». Ad affermarlo è il presidente dell’Emilia...        Open
# 3    L’  tra Giorgia Meloni e Matteo Salvini è serv...        Open
# 4    Il   di   mette nel mirino reddito di cittadin...        Open
# ..                                                 ...         ...
# 129  Il segretario della Lega   farà il punto con i...        Open
# 130  Il   scricchiola sotto il peso della crisi di ...        Open
# 131  I tessitori sono rimasti all’opera fino alle 2...        Open
# 132  , a ruota libera all’assemblea di Italia Viva ...        Open
# 133  Su cinque diversi scenari per la simulazione d...        Open
#
# [134 rows x 4 columns]
